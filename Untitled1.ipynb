# %% [markdown]
# <a href="https://colab.research.google.com/github/lkoenigs-2025/Module-4/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
    def romanToInt(self, s: str) -> int:
        convert = 0
        new_list = []
        roman_numerals = {"I" : 1, "V" : 5, "X" : 10, "L" : 50, "C" : 100, "D" : 500, "M" : 1000}
        for key,value in roman_numerals.items():
          for i in range(len(s)):
            if s[i] == "I" and s[i+1] == "V":
              roman_numerals[key] = 4
              print(s[i])
            if s[i] == "I" and s[i+1] == "X":
              value = 9
              print(s[i])
            if s[i] == "X" and s[i+1] == "L":
              value = 40
              print(s[i])
            if s[i] == "X" and s[i+1] == "C":
              value = 90
              print(s[i])
            if s[i] == "C" and s[i+1] == "D":
              value = 400
              print(f'400: {s[i]}')
            if s[i] == "C" and s[i+1] == "M":
              value = 900
              print(f'900: {s[i]}')
            #if s[i] not in new_list:
              #new_list.append(f'{key} = {value}')
            #else:
              #indx = new_list.index(s[i])
              #new_list.pop(indx)
              #new_list.append(f'{key} = {value}')
        return new_list
    print(romanToInt(('I', 'V', 'X', 'L', 'C', 'D', 'M'), "MCMXCIV"))
# Out:
# 900: C
# X
# I
# 900: C
# X
# I
# 900: C
# X
# I
# 900: C
# X
# I
# 900: C
# X
# I
# 900: C
# X
# I
# 900: C
# X
# I
# []
