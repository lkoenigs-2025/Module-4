# %% [markdown]
# <a href="https://colab.research.google.com/github/lkoenigs-2025/Module-4/blob/main/MCON_232_Dictionaries_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Leah Koenigsberg
# ## Topic : Dictionaries Lab

# %%
#Dictionary:
courses = {"MCON 232" : "Advanced Programming",
           "MCON 141" : "Introduction to Programming"}
print(courses)
# Out:
# {'MCON 232': 'Advanced Programming', 'MCON 141': 'Introduction to Programming'}

# %%
# can do like this:
courses = {}

#and this overides it...
courses = {"MCON 232" : "Advanced Programming",
           "MCON 141" : "Introduction to Programming"}

#add onto dict
courses["MCON 264"] = "Data Structures I"

print(courses)
# Out:
# {'MCON 232': 'Advanced Programming', 'MCON 141': 'Introduction to Programming', 'MCON 264': 'Data Structures I'}

# %%
#retrieve value from dict:
print(courses["MCON 264"])
# Out:
# Data Structures I

# %%
#might want to do try/except...
try:
  print(courses["MCON 641"])
except KeyError as key:    #if does not exist: will throw keyerror
  print("Key not found", key)
# Out:
# Key not found 'MCON 641'

# %%
#in and not in: only works with keys NOT values
"MCON 232" in courses #wld return true
"Advanced Programming" in courses #False cuz cant find values
"MCON 664" not in courses #true cuz not in
# Out:
# True

# %%
#must define dict before:
houses = {}
#will throw a name error if houses not defined on top
houses["North Ave"] = "New Rochelle"

# %%
#store value from a key of a dict:
value = courses["MCON 264"]
print(value)
# Out:
# Data Structures I

# %%
#delete a key:
del(houses["North Ave"])
print(houses)
#retuns empty dict cuz there is none left inside
# Out:
# {}

# %%
#len function- how many are in dict:
print(len(houses))
print(len(courses))
# Out:
# 0
# 3

# %%
#can mix data types
one_student = {"name" : "Chaya",
               "Age" : "19",
               "GPA" : 3.9,
               "courses" : ["MCON 232", "MCON 141", "MCON 241"],   #canout list as value
               5: "number", #can mix data types on wither side
               ("data", "data2") : "Hello" #can have a tuple as a key
               }

print(one_student)
# Out:
# {'name': 'Chaya', 'Age': '19', 'GPA': 3.9, 'courses': ['MCON 232', 'MCON 141', 'MCON 241'], 5: 'number', ('data', 'data2'): 'Hello'}

# %%
leah = {"name" : "Leah",
        "Age" : 19,
        "Address" : ["Brockton Rd", "Spring Valley", "NY", "10977"],
        "Job" : "Teacher"}

print(leah)
# Out:
# {'name': 'Leah', 'Age': 19, 'Address': ['Brockton Rd', 'Spring Valley', 'NY', '10977'], 'Job': 'Teacher'}

# %%
#LOOP THROUGH DICT:
#loop thru valus: use .values()
#or .items for key value pairs

print("Get keys")
for key in courses:
  print(key)

print()
print("Get keys and values")
for key in courses:
  print(key, ":", courses[key]) #gets the value once have keys

print()
print("Print values")
for value in courses.values():
  print(value)  #no way to get the keys in this way

#get value pairs using items()
print()
for key, value in courses.items():
  print(f"{key} : {value}")

#enumerate:
print()
for index, (key, value) in enumerate(courses.items()):
  print(f"{index}: {key} : {value}")  #useful for formatting
# Out:
# Get keys
# MCON 232
# MCON 141
# MCON 264
#
# Get keys and values
# MCON 232 : Advanced Programming
# MCON 141 : Introduction to Programming
# MCON 264 : Data Structures I
#
# Print values
# Advanced Programming
# Introduction to Programming
# Data Structures I
#
# MCON 232 : Advanced Programming
# MCON 141 : Introduction to Programming
# MCON 264 : Data Structures I
#
# 0: MCON 232 : Advanced Programming
# 1: MCON 141 : Introduction to Programming
# 2: MCON 264 : Data Structures I

# %%
student = {}
student[1] = "Leah"
student.get(1, "Leah")
print(student)

#if key doesnt exist then that key value pair will be added to dict
student.setdefault(2, "Reizi")
print(student)

#merges the two dict:
courses |= student
print(courses)

#we can pop
courses.popitem() #pops last item- no argument
print(courses)

courses.pop(3, "Ruchama") # if it doesnt exist nothing changes
courses.pop(1, "Leah") #pops off
print(courses)
# Out:
# {1: 'Leah'}
# {1: 'Leah', 2: 'Reizi'}
# {'MCON 232': 'CHange Course', 'MCON 141': 'Introduction to Programming', 'MCON 264': 'Data Structures I', 1: 'Leah', 2: 'Reizi'}
# {'MCON 232': 'CHange Course', 'MCON 141': 'Introduction to Programming', 'MCON 264': 'Data Structures I', 1: 'Leah'}
# {'MCON 232': 'CHange Course', 'MCON 141': 'Introduction to Programming', 'MCON 264': 'Data Structures I'}

# %%
#will print the whole dict cuz references whole dict
LAS = courses
print(LAS)

#this will change mcon 232 from courses
LAS["MCON 232"] = "Change Course"
print(courses)

#to make a shallow copy:
print()
LAS = courses.copy()
LAS["MCON 232"] = "New Course"
print(courses)
print(LAS)
#This will only copy top level of dict: which can be a problem if nested dic/ nested list:
#So instead u wld do .deepcopy()
# Out:
# {'MCON 232': 'Change Course', 'MCON 141': 'Introduction to Programming', 'MCON 264': 'Data Structures I'}
# {'MCON 232': 'Change Course', 'MCON 141': 'Introduction to Programming', 'MCON 264': 'Data Structures I'}
#
# {'MCON 232': 'Change Course', 'MCON 141': 'Introduction to Programming', 'MCON 264': 'Data Structures I'}
# {'MCON 232': 'New Course', 'MCON 141': 'Introduction to Programming', 'MCON 264': 'Data Structures I'}

# %%
for values in courses.values():
  if values.find("I") != -1:
    print(values)

#or find keys:
print()
for keys in courses:
  if keys.find("MCON") != -1:
    print(keys)
# Out:
# Introduction to Programming
# Data Structures I
#
# MCON 232
# MCON 141
# MCON 264

# %%
#prints as a list
#prints values in dict as list
print(courses.values())
#print keys in dict as list
print(courses.keys())
#prints keys and values as tuple in a list
print(courses.items())
# Out:
# dict_values(['Change Course', 'Introduction to Programming', 'Data Structures I'])
# dict_keys(['MCON 232', 'MCON 141', 'MCON 264'])
# dict_items([('MCON 232', 'Change Course'), ('MCON 141', 'Introduction to Programming'), ('MCON 264', 'Data Structures I')])

# %%
#pop off and then print the value you popped off
value = courses.pop("MCON 232", "Change Course")
print(value)
#new dict
print(courses)
# Out:
# {'MCON 141': 'Introduction to Programming', 'MCON 264': 'Data Structures I'}
# Change Course

# %%
#Shallow copy NOT deep
#{} makes a new dict
new_dictionary = {k:v for k,v in courses.items()} # can add an if also
print(new_dictionary)
# Out:
# {'MCON 141': 'Introduction to Programming', 'MCON 264': 'Data Structures I'}

# %%
numbers = {1: "ONE",
           2: "TWO",
           3: "THREE",
           4: "FOUR",
           5: "FIVE"}
print(numbers)

for key in numbers:
  if key % 2 == 0:
    print(key)

print(courses)
print(f'{courses["MCON 264"]} {courses["MCON 141"]}')
# Out:
# {1: 'ONE', 2: 'TWO', 3: 'THREE', 4: 'FOUR', 5: 'FIVE'}
# 2
# 4
# {'MCON 141': 'Introduction to Programming', 'MCON 264': 'Data Structures I'}
# Data Structures I Introduction to Programming

# %%
#not on exam 1:
students = {"Chana" : {"student1" : "Chana", "address" : "qwertyuiop", "age" : "19"},
            "Leah" : {"student1" : "Leah", "address" : "zxcvbnm", "age" : "19"},
            "Reizi" : {"student1" : "Reizi", "address" : "asdfghjkl", "age" : "20"},}
print(students)
# Out:
# {'student1': 'Chana', 'student2': 'Leah', 'student3': 'Reizi', 'student4': 'Shaked', 'student5': 'Ruchama'}

# %% [markdown]
# ## Assignment: Majority Element (Easy)
# Problem Given a list of integers nums, return the element that appears more   than n/2 times.
# You may assume a majority element always exists.
#
# Example
# nums = [3, 2, 3] → 3
# nums = [2, 2, 1, 1, 1, 2, 2] → 2
#
# Goal Solve using a dictionary that maps: number -> count.

# %%
def majority_elements(nums : list):
  counts = {}

#iterates thru list for each num
  for i in nums:
    #if does or doesnt exist, store as key in dict put 0 and add 1
    #if exists then u get the value and keep adding 1 so value for 4 changes
    counts[i] = counts.get(i, 0) + 1

    #now return element that is there more than 1
    if counts[i] > len(nums) // 2:
      return i

print(majority_elements([1,2,3,4,4,4,4,4]))
# Out:
# 4
